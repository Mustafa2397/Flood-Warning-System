# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Master_TimeSeries_Data.csv')

# %%
print("--- Data Info ---")
print(df.info())
# Out:
# --- Data Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913488 entries, 0 to 913487
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Region_ID         913488 non-null  int64
#  1   Date              913488 non-null  object
#  2   Precipitation_mm  913488 non-null  float64
#  3   Tasmax_C          913488 non-null  float64
#  4   Tasmin_C          913488 non-null  float64
#  5   Year              913488 non-null  int64
#  6   Month             913488 non-null  int64
#  7   Tasmean_C         913488 non-null  float64
#  8   Temp_Range_C      913488 non-null  float64
#  9   Scenario          913488 non-null  object
#  10  Period            913488 non-null  object
#  11  Model             913488 non-null  object
# dtypes: float64(5), int64(3), object(4)
# memory usage: 83.6+ MB
# None

# %%
print("\n--- First 5 Rows ---")
print(df.head())
# Out:
# --- First 5 Rows ---
#    Region_ID        Date  Precipitation_mm   Tasmax_C   Tasmin_C  Year  Month  \
# 0       1355  2036-01-01               0.0  28.378601  18.036804  2036      1
# 1       1355  2036-01-02               0.0  29.370209  17.826080  2036      1
# 2       1355  2036-01-03               0.0  28.941071  17.755859  2036      1
# 3       1355  2036-01-04               0.0  29.885529  16.450592  2036      1
# 4       1355  2036-01-05               0.0  30.264648  17.363770  2036      1
#
#    Tasmean_C  Temp_Range_C Scenario     Period                  Model
# 0  23.207702     10.341797   rcp4.5  2036-2065  SMHI_RCA4MOHC_HadGEM2
# 1  23.598145     11.544129   rcp4.5  2036-2065  SMHI_RCA4MOHC_HadGEM2
# 2  23.348465     11.185212   rcp4.5  2036-2065  SMHI_RCA4MOHC_HadGEM2
# 3  23.168060     13.434937   rcp4.5  2036-2065  SMHI_RCA4MOHC_HadGEM2
# 4  23.814209     12.900878   rcp4.5  2036-2065  SMHI_RCA4MOHC_HadGEM2

# %%
print("\n--- Descriptive Statistics ---")
print(df.describe())
# Out:
# --- Descriptive Statistics ---
#            Region_ID  Precipitation_mm       Tasmax_C       Tasmin_C  \
# count  913488.000000     913488.000000  913488.000000  913488.000000
# mean      742.500000          2.133872      32.394671      18.763293
# std       510.932679          8.372180       5.822778       4.909914
# min        83.000000          0.000000    -275.538813    -278.431977
# 25%        99.000000          0.000000      28.612732      16.346702
# 50%       809.000000          0.000000      30.996368      18.387909
# 75%      1300.000000          0.140205      34.668243      20.653351
# max      1355.000000        398.820488      57.291504      40.834656
#
#                 Year          Month      Tasmean_C   Temp_Range_C
# count  913488.000000  913488.000000  913488.000000  913488.000000
# mean     2041.111056       6.496611      25.578982      13.631377
# std        33.255603       3.445973       5.130684       3.275410
# ...

# %%
print("\n--- Missing Values ---")
print(df.isnull().sum())
# Out:
# --- Missing Values ---
# Region_ID           0
# Date                0
# Precipitation_mm    0
# Tasmax_C            0
# Tasmin_C            0
# Year                0
# Month               0
# Tasmean_C           0
# Temp_Range_C        0
# Scenario            0
# Period              0
# Model               0
# dtype: int64

# %%
print("\n--- Column Names ---")
print(df.columns.tolist())
# Out:
# --- Column Names ---
# ['Region_ID', 'Date', 'Precipitation_mm', 'Tasmax_C', 'Tasmin_C', 'Year', 'Month', 'Tasmean_C', 'Temp_Range_C', 'Scenario', 'Period', 'Model']

# %%
print("\n--- Data Types ---")
print(df.dtypes)
# Out:
# --- Data Types ---
# Region_ID             int64
# Date                 object
# Precipitation_mm    float64
# Tasmax_C            float64
# Tasmin_C            float64
# Year                  int64
# Month                 int64
# Tasmean_C           float64
# Temp_Range_C        float64
# Scenario             object
# Period               object
# Model                object
# dtype: object
